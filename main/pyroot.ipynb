# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
def func(x):
    return 2 * np.sin(0.7 * x - 2)


x = np.arange(0, 30, 1)
y = func(x)
desv = [
    4.19,
    4.73,
    2.13,
    4.59,
    8.57,
    1.29,
    2.61,
    6.1,
    2.05,
    5.77,
    1.94,
    6.05,
    2.64,
    1.61,
    7.65,
    1.56,
    1.02,
    6.89,
    1.49,
    1.98,
    8.83,
    1.01,
    6.53,
    5.14,
    6.29,
    5.05,
    3.78,
    5.7,
    6.43,
    7.9,
]
i = 0
for u in desv:
    desv[i] = desv[i] / 100
    i += 1

y = y + desv
print(desv)
print(y)
plt.plot(x, func(x), linestyle="-")
plt.plot(x, y)

np.savetxt("../y.txt", np.c_[x, y])
# Out:
# [0.04190000000000001, 0.0473, 0.0213, 0.045899999999999996, 0.0857, 0.0129, 0.026099999999999998, 0.061, 0.020499999999999997, 0.057699999999999994, 0.0194, 0.0605, 0.0264, 0.0161, 0.0765, 0.015600000000000001, 0.0102, 0.0689, 0.0149, 0.019799999999999998, 0.0883, 0.0101, 0.0653, 0.051399999999999994, 0.0629, 0.050499999999999996, 0.0378, 0.057, 0.0643, 0.079]
# [-1.77669485 -1.87981637 -1.10798495  0.24556683  1.52041218  2.00788997
#   1.64309281  0.53949866 -0.86454089 -1.77463187 -1.89844855 -1.04087109
#   0.25949841  1.47403808  2.07358669  1.61257423  0.45597983 -0.84617179
#  -1.83065084 -1.8882385  -0.98484584  0.27656408  1.54605178  2.05001878
#   1.63940413  0.46343496 -0.90704397 -1.80124803 -1.833389   -0.96561718]
